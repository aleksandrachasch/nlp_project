# %% [markdown]
# Есть две идеи:
# ### 1-ая идея:
#
# - Обучение:
# Вытащить из корпуса все positive / negative слова
# Векторизовать каждое слово с помощью word2vec
# Написать простой классификатор (вектор - класс)
#
# - Тестирование:
# На вход поступает слово
# Вектурезуем его с помощью word2vec и делаем predict
#
#
# ### 2-ая идея
#
# - Обучение
# Подать на word2vec сначала негативные слова, векторизовать, записать в массив.
# Потом подать на word2vec позитивные, векторизовать.
# Получится два облака.
#
# - Тестирование
# Далее входные слова сравнивать с каждым из этих двух облаков.
# Берем входное слово, сравниваем его с каждым словом из позитивного облака, запиисываем расстояние.
# Потом сравниваем с каждым словом из негативного облака и тоже считаем расстояние.
# Сравниваем результаты по расстояниям по разным облакам.

# %%
# -*- coding: utf-8 -*-
from __future__ import division
import re
import random
import pandas as pd
import numpy as np
from lxml import etree

import pymorphy2
import math
from nltk.tokenize import TreebankWordTokenizer
from stop_words import get_stop_words

from text_cleanisation_NLP import text_to_words
import gensim

import matplotlib.pyplot as plt

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.base import TransformerMixin
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.grid_search import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import fbeta_score, make_scorer
from sklearn import cross_validation

morph = pymorphy2.MorphAnalyzer()
tokenizer = TreebankWordTokenizer()

RUS_LETTERS = u'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
# Out:
# /usr/local/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.5/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
def parse_xml(filename):
    with open(filename, encoding='utf-8') as f:
        xml = f.read()

    dict = {}
    text = []
    category = []
    sentiment = []
    term = []

    root = etree.fromstring(xml)
    for child in root:
        for aspect in child[3]:
            if aspect.attrib['type'] == 'implicit' and aspect.attrib['sentiment']!= 'both' and aspect.attrib['sentiment']!= 'neutral':
                text.append(child[2].text)
                category.append(aspect.attrib['category'])
                sentiment.append(aspect.attrib['sentiment'])
                term.append(aspect.attrib['term'])

    dict['text'] = text
    dict['category'] = category
    dict['sentiment'] = sentiment
    dict['term'] = term

    
    return dict

# %%
text_train = parse_xml('SentiRuEval_rest_markup_train.xml')
text_test = parse_xml('SentiRuEval_rest_markup_test.xml')

# %%
# Создаем датафрейм из тестового и тренировочного корпуса

df1 = pd.DataFrame(text_train)
df2 = pd.DataFrame(text_test)

frames = [df1, df2]
df = pd.concat(frames)

# %%
df.head()
# Out:
#    category sentiment     term  \
# 0      Food  positive  вкусное
# 1  Interior  positive   уютный
# 2      Food  positive  вкусные
# 3  Interior  positive    уютно
# 4  Interior  positive  красиво
#
#                                                 text
# 0  День 8-го марта прошёл, можно и итоги подвести...
# 1  День 8-го марта прошёл, можно и итоги подвести...
# 2  Отмечали в этом ресторане день рождение на пер...
# 3  Отмечали в этом ресторане день рождение на пер...
# 4  Отмечали в этом ресторане день рождение на пер...

# %%
df.describe()
# Out:
#        category sentiment    term  \
# count      1367      1367    1367
# unique        5         2     505
# top        Food  positive  вкусно
# freq        538      1235     137
#
#                                                      text
# count                                                1367
# unique                                                371
# top     Отмечали свадьбу 15 марта. Ах-Ах!!! Замечатель...
# freq                                                   14

# %%
df.groupby('sentiment').describe()
# Out:
#                  category    term  \
# sentiment
# negative  count       132     132
#           unique        5     105
#           top        Food  дорого
#           freq         54       5
# positive  count      1235    1235
#           unique        5     402
#           top        Food  вкусно
#           freq        484     137
#
#                                                                text
# sentiment
# negative  count                                                 132
#           unique                                                 91
#           top     Посещали это заведение 2 раза, ощущения разные...
#           freq                                                    4
# positive  count                                                1235
#           unique                                                353
#           top     Отмечали свадьбу 15 марта. Ах-Ах!!! Замечатель...
#           freq                                                   14

# %%
# Делаем датасет сбалансированным
df = pd.concat([df[df['sentiment'] == 'positive'].sample(frac=1)[:132], df[df['sentiment'] == 'negative']]).sample(frac=1)
# Out:
# Сделаем датасет сбалансированным

# %%
# Загружаем модель
m = 'web_0_300_20.bin'
model = gensim.models.KeyedVectors.load_word2vec_format(m, binary=True)
model.init_sims(replace=True)

# %%
transit = {'ADJF':'ADJ',
'ADJS' : 'ADJ',
'ADVB' : 'ADV',
'COMP' : 'ADV',
'CONJ' : 'CCONJ',
'GRND' : 'VERB',
'INFN' : 'VERB',
'INTJ' : 'INTJ',
'LATN' : 'X',
'NOUN' : 'NOUN',
'NPRO' : 'PRON',
'NUMB' : 'NUM',
'NUMR' : 'NUM',
'PNCT' : 'PUNCT' ,
'PRCL' : 'PART',
'PRED' : 'ADV',
'PREP' : 'ADP',
'PRTF' : 'ADJ',
'PRTS' : 'VERB',
'ROMN' : 'X',
'SYMB' : 'SYM',
'UNKN' : 'X',
'VERB' : 'VERB'}

robj = re.compile('|'.join(transit.keys()))

def cleanization(text):
    for line in text:
        # 1. Все буквы в нижний регистр
        text_text = text.lower()

        # 2. Удаление всех небукв
        letters_only = ''
        for _c in text_text:
            if _c in RUS_LETTERS:
                letters_only += _c
            else:
                letters_only += ' '

        # 3. Заменяем множественные пробелы
        while '  ' in letters_only:
            letters_only = letters_only.replace('  ', ' ')

        # 4. Токенизация
        word_list = tokenizer.tokenize(letters_only)

        # 5. Лемматизация
        clean_word_list = [morph.parse(word)[0].normal_form for word in word_list]  # лемматизация
    
        # 6. * Удаление стоп-слов + добавление тегов - части речи
        # meaningful_words = [word for word in clean_word_list if word not in get_stop_words('ru')] # стоп-слова
        meaningful_words = [str(word) + '_' + robj.sub(lambda m: transit[m.group(0)], str(morph.parse(word)[0].tag.POS)) for word in clean_word_list]
        return ' '.join(meaningful_words)

# %%
# Проверка работы функции cleanization
cleanization('Я сегодня съела очень много мороженого')
# Out:
# 'я_PRON сегодня_ADV съесть_VERB очень_ADV много_ADV мороженое_NOUN'

# %%
from __future__ import division
def mean(a):
    return sum(a) / len(a)


def word2vec_mean(text):
    """Усредняет вектор слов."""
    arr = []
    clean_text = cleanization(text)
    # для каждого слова в тексте выводим его вектор
    for word in clean_text.split(' '):
        print(word)
        # есть ли слово в модели? Может быть, и нет
        if word in model:
            arr.append(model[word])
    if len(list(map(mean, zip(*arr)))) != 0:
        return list(map(mean, zip(*arr)))
    else:
        return [0 for i in range(0, 300)]



class FunctionFeaturizer(TransformerMixin):
    """ Для создания своего вектора я использовала усредненную векторизацию с помощью word2vec"""
    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        fvs = []
        # fvs = word2vec_mean(X)  # если подавать по словам, а не датафрейм
        for datum in X:
            print(datum)
            fv = word2vec_mean(datum)
            fvs.append(fv)
        return np.array(fvs)

# %%
# Проверка векторизатора
df1 = pd.DataFrame({'text':['хороший', 'очень хороший'], 'class':['1', '0']})
w2v_featurizer = FunctionFeaturizer() 
x = w2v_featurizer.transform(df1.text)
x
# Out:
# хороший
# хороший_ADJ
# очень хороший
# очень_ADV
# хороший_ADJ
# array([[  7.33737042e-03,  -2.96452902e-02,   6.50390610e-02,
#           3.19109261e-02,   4.67816442e-02,  -6.75016195e-02,
#           1.34420572e-02,  -1.00418180e-01,   6.53345138e-02,
#           2.46328283e-02,  -7.88142625e-03,  -7.19515756e-02,
#          -3.37976255e-02,   2.32609529e-02,   5.84121747e-03,
#          -1.20705580e-02,  -3.55095118e-02,   5.70581928e-02,
#          -5.28854914e-02,   6.36451971e-03,   4.01164368e-02,
#          -4.82101887e-02,  -5.52522391e-02,   1.19763343e-02,
#           5.54701425e-02,  -1.48677127e-02,  -1.01240285e-01,
#           4.72908318e-02,   4.67002094e-02,   6.18545637e-02,
#          -1.20627820e-01,  -9.26931016e-03,   3.15161943e-02,
#           2.23013968e-03,  -3.23524722e-03,   3.60459499e-02,
#           2.32331306e-02,   4.34190817e-02,  -6.47412986e-02,
#           1.71083870e-04,   2.29924582e-02,  -2.39938311e-02,
#           3.65550630e-02,   5.90851046e-02,   4.88272235e-02,
#          -6.65662438e-02,   1.19906226e-02,   6.42403737e-02,
#          -5.50095029e-02,  -7.59308860e-02,   5.68110570e-02,
#           1.96577795e-02,   3.51579078e-02,   2.37929765e-02,
#           3.73131670e-02,  -8.25387146e-03,  -4.56062071e-02,
#           1.07027721e-02,   5.35744131e-02,   4.60452400e-02,
#          -1.07583538e-01,  -4.46126126e-02,  -1.11628845e-01,
#           1.55463954e-02,  -2.33858135e-02,  -1.63231026e-02,
#          -5.27138077e-02,  -3.21586095e-02,  -9.31867864e-03,
#          -6.00871183e-02,   7.69144297e-03,  -9.67709646e-02,
#          -3.65174375e-02,  -1.16793297e-01,   1.79343503e-02,
#           8.32767859e-02,  -8.87006149e-02,  -1.39374146e-02,
#           1.08059477e-02,   3.24390307e-02,   4.06219028e-02,
#          -3.57064046e-02,   4.15105745e-02,  -4.48481478e-02,
#          -8.47954070e-04,  -4.04333472e-02,   7.42429942e-02,
#          -3.70885395e-02,  -3.43977138e-02,  -1.01012178e-01,
#          -9.52832699e-02,   5.99603308e-03,   3.62775512e-02,
#           6.91484362e-02,  -4.79201265e-02,   2.69586071e-02,
#          -3.59099507e-02,   4.41464968e-02,   5.36971316e-02,
#          -6.23969026e-02,  -4.98496033e-02,  -2.95065157e-02,
#           5.80576025e-02,   1.33435766e-03,   5.38080595e-02,
#          -4.49722148e-02,  -1.61047261e-02,  -5.46122789e-02,
#           5.43172918e-02,   4.96269315e-02,   9.53349844e-02,
#          -1.00276871e-02,   4.93593328e-02,  -1.17983848e-01,
#           3.16709429e-02,  -6.36941344e-02,   4.82458957e-02,
#          -1.84206963e-02,   7.55869597e-02,   1.92815997e-02,
#          -8.05545822e-02,  -7.87510872e-02,   1.00902066e-01,
#          -7.52724335e-02,   6.67342916e-02,   6.79232227e-03,
#           6.14058180e-03,  -2.27839909e-02,   3.02080251e-02,
#          -8.91474541e-03,  -1.93737894e-02,  -6.65677572e-03,
#           3.47155696e-02,   2.52589174e-02,  -6.80364338e-02,
#          -1.73212456e-02,   1.04035735e-02,  -6.94417050e-02,
#           2.38599819e-02,   3.48898533e-02,  -3.32057584e-02,
#          -5.31168990e-02,   8.12205821e-02,   1.29857415e-02,
#           1.68297514e-02,  -6.16899189e-02,  -6.45232648e-02,
#          -8.45774375e-02,  -4.42215232e-02,   4.98112198e-03,
#          -1.23581174e-02,   1.21348463e-02,  -5.76664861e-02,
#          -5.49393564e-02,   6.29955158e-03,   3.60645354e-02,
#          -5.71779725e-02,   6.13463111e-03,  -6.06456390e-02,
#          -4.76287659e-02,   2.62512197e-02,   3.57758151e-02,
#           4.79579009e-02,  -2.75714351e-02,   1.42037752e-02,
#           2.48106197e-02,   1.37235802e-02,  -1.96699314e-02,
#           3.16643091e-02,  -3.06139095e-02,  -6.48813350e-02,
#           6.07022364e-03,  -1.58029944e-02,   9.93062891e-02,
#          -4.93248850e-02,  -2.42605051e-02,  -8.02482531e-03,
#          -8.86113197e-03,   8.02896060e-02,  -1.74022880e-02]])

# %%
# Делим корпус на тестовый и тернировочный
X_train, X_test, y_train, y_test = train_test_split(df['term'], df['sentiment'], test_size=0.1)

# %%
X_train.head()
# Out:
# 496         суховато
# 157    радовали глаз
# 522        не вкусно
# 448           уютную
# 108           вкусно
# Name: term, dtype: object

# %%
y_train.head()
# Out:
# 496    negative
# 157    positive
# 522    negative
# 448    positive
# 108    positive
# Name: sentiment, dtype: object

# %%
X_train.describe()
# Out:
# count        237
# unique       175
# top       вкусно
# freq          10
# Name: term, dtype: object

# %%
def do_smth_with_model(data_train, class_train, data_test, class_test, steps):
    print('\nModel train')
    pipeline = Pipeline(steps=steps)

    cv_results = cross_val_score(pipeline,
                                 data_train,
                                 class_train,
                                 cv=10,
                                 scoring='accuracy',
                                )
    print(cv_results.mean(), cv_results.std())

    pipeline.fit(data_train, class_train)
    class_predicted = pipeline.predict(data_test)
    print(class_predicted)

    print(classification_report(class_test, class_predicted ))

    return pipeline, class_predicted

# %%
w2v_featurizer = FunctionFeaturizer()  # создание своего векторизатора

# %%
# Свой векторизатор
print('\nCustom Transformer')
lr_pipeline, label_predicted = do_smth_with_model(X_train, y_train,
                                               X_test, y_test, 
                                               steps=[('custom', w2v_featurizer),
                                                      ('classifier', LogisticRegression())])
# Out:
# Custom Transformer
#
# Model train
# 0.86502173913 0.0790571610235
# ['positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'negative' 'negative' 'positive' 'positive' 'negative' 'negative'
#  'positive' 'positive' 'negative' 'positive' 'positive' 'negative'
#  'positive' 'positive' 'negative' 'negative' 'positive' 'negative'
#  'positive' 'negative' 'positive']
#              precision    recall  f1-score   support
#
#    negative       1.00      0.91      0.95        11
#    positive       0.94      1.00      0.97        16
#
# avg / total       0.97      0.96      0.96        27

# %%
# Свой векторизатор
print('\nCustom Transformer')
etx_pipeline, label_predicted = do_smth_with_model(X_train, y_train,
                                               X_test, y_test, 
                                               steps=[('custom', w2v_featurizer),
                                                      ('classifier', ExtraTreesClassifier())])
# Out:
# Custom Transformer
#
# Model train
# 0.81934057971 0.07840661717
# ['positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'negative' 'negative' 'positive' 'positive' 'negative' 'negative'
#  'positive' 'positive' 'negative' 'positive' 'positive' 'negative'
#  'positive' 'positive' 'negative' 'negative' 'positive' 'negative'
#  'positive' 'negative' 'positive']
#              precision    recall  f1-score   support
#
#    negative       1.00      0.91      0.95        11
#    positive       0.94      1.00      0.97        16
#
# avg / total       0.97      0.96      0.96        27

# %% [markdown]
# ## Проверка работы модели на наших тестовых коллокациях

# %%
df1 = pd.DataFrame({'text':['отличный выбор', 'не советуем', 'очень советуем', 'очень дорого', 'выше всяких похвал', 'в общем прекрасно', 'нам все понравилось']})
# , 'в целом ничего', 'отвратительный', 'быстро', 'очень плохое обслуживание', 'отличное меню', 'хороший', 'вкусный', 'замечательный', 'приятный', 'красивый', 'отличный'

# %%
df1.head()
# Out:
#                 text
# 0     отличный выбор
# 1  в общем прекрасно

# %%
x = w2v_featurizer.transform(df1.text)  # векторизуем наши слова
# Out:
# отличный выбор
# отличный_ADJ
# выбор_NOUN
# в общем прекрасно
# в_ADP
# общий_ADJ
# прекрасно_ADV

# %%
x
# Out:
# array([[-0.02267521, -0.02004785, -0.0533559 ,  0.02998884,  0.02433738,
#         -0.04528048,  0.02503823, -0.06758565,  0.10700708,  0.11197043,
#          0.0055064 , -0.02449975, -0.04704763,  0.08442327, -0.0074172 ,
#         -0.05136339, -0.10666844,  0.02820366, -0.02467697,  0.00714388,
#         -0.01181722, -0.06201697, -0.09022723,  0.00912218,  0.0017081 ,
#          0.00687049, -0.1338036 ,  0.006457  ,  0.0320274 , -0.05980522,
#         -0.10798008, -0.03101333, -0.01886609, -0.00393408,  0.00349874,
#         -0.03655685, -0.04868337,  0.01883063,  0.01420446, -0.01032911,
#          0.04063499,  0.02868253,  0.03263469,  0.07891723,  0.04877253,
#         -0.04752337, -0.02643839,  0.0075727 , -0.0302735 , -0.01208394,
#         -0.0765805 , -0.07310214, -0.01387591,  0.05331096,  0.02760612,
#         -0.0274395 , -0.09663586,  0.00373642,  0.03719021, -0.02005388,
#         -0.01238265, -0.04853695, -0.00077484,  0.04640021,  0.01345689,
#          0.0307044 , -0.02597226,  0.00235111, -0.00921766, -0.00177166,
#          0.01371905,  0.00861111, -0.02077969, -0.03338404,  0.03146325,
#          0.03114052, -0.06224102,  0.02123719, -0.0176468 ,  0.04244401,
#          0.09807049, -0.02571135,  0.06358497, -0.00524489,  0.00541868,
#         -0.03171473,  0.08254547, -0.00972748, -0.03339462, -0.02414217,
#          0.01934511,  0.01370559,  0.02457651,  0.0009902 , -0.02487274,
#          0.03188304, -0.01769318,  0.00389012,  0.01269333, -0.04399293,
#         -0.03786808, -0.02635977, -0.00176007,  0.0116202 ,  0.0844323 ,
#         -0.10676384,  0.01049203, -0.08649076,  0.08099748,  0.06834647,
#          0.06334467, -0.01460514,  0.07347159, -0.08964525,  0.05731819,
#          0.00834527,  0.03660245,  0.00428277, -0.00117173, -0.03401708,
#         -0.0560115 ,  0.01142813, -0.02074037, -0.00589763, -0.01224464,
#          0.03119796,  0.02324139,  0.0252704 , -0.02359171, -0.07720885,
#         -0.0590322 , -0.02360948,  0.02639378,  0.04664383,  0.06079491,
#         -0.01775142, -0.04358811,  0.01911902,  0.03383019, -0.01951719,
#          0.00607744,  0.00687551,  0.02834935, -0.01396969, -0.11692556,
#         -0.00136945,  0.02789203,  0.01996577, -0.04332141, -0.01472172,
#          0.01022736, -0.02779202, -0.06651334, -0.0437145 , -0.06228876,
#          0.05282985, -0.02930608, -0.03425016,  0.04656704,  0.04728497,
#         -0.06210216,  0.01198277,  0.00525429, -0.04431195, -0.06198619,
#          0.01265675, -0.04579742, -0.01406525, -0.03407057, -0.00904568,
#         -0.04576977,  0.06746124, -0.04809308, -0.02467437,  0.06768507,
#          0.0126727 , -0.05873773, -0.00275373, -0.05276001, -0.05398957,
#          0.03520905,  0.02452845,  0.01329283, -0.05568141,  0.00787171,
#         -0.01083782, -0.00350761, -0.06132992,  0.02059018, -0.05131358]])

# %%
lr_model = LogisticRegression()
lr_model.fit(w2v_featurizer.transform(X_train), y_train)
cv_results = cross_val_score(lr_model, w2v_featurizer.transform(X_train), y_train, cv=10, scoring='accuracy')
print(cv_results.mean(), cv_results.std())
lr_model.predict(x)
# Out:
# суховато
# суховато_ADV
# радовали глаз
# радовать_VERB
# глаз_NOUN
# не вкусно
# не_PART
# вкусно_ADV
# уютную
# уютный_ADJ
# вкусно
# вкусно_ADV
# не из дешевых
# не_PART
# из_ADP
# дешёвый_ADJ
# вежлив
# вежливый_ADJ
# Вкусное
# вкусный_ADJ
# внимателен
# внимательный_ADJ
# приветливые
# приветливый_ADJ
# забывчивость
# забывчивость_NOUN
# быстро
# быстро_ADV
# хамское
# хамский_ADJ
# оперативно
# оперативно_ADV
# места мало
# место_NOUN
# мало_ADV
# приветливый
# приветливый_ADJ
# вкусные
# вкусный_ADJ
# уютная
# уютный_ADJ
# любезный
# любезный_ADJ
# вежливые
# вежливый_ADJ
# сытные
# сытный_ADJ
# вкусно
# вкусно_ADV
# грубых
# грубый_ADJ
# игнором
# игнором_NOUN
# доброжелательных
# доброжелательный_ADJ
# дорогой
# дорогой_ADV
# не вкусный
# не_PART
# вкусный_ADJ
# чуть теплым
# чуть_ADV
# тёплый_ADJ
# жесткое
# жёсткий_ADJ
# не дешево
# не_PART
# дёшево_ADV
# невкусные
# невкусный_ADJ
# претензионная
# претензионный_ADJ
# суховато
# суховато_ADV
# доброжелательная
# доброжелательный_ADJ
# удобно
# удобно_ADV
# приветливые
# приветливый_ADJ
# таяло во рту
# таять_VERB
# в_ADP
# рот_NOUN
# нерасторопных
# нерасторопный_ADJ
# чистенько
# чистенько_ADV
# непрожарена
# непрожарить_VERB
# уютный
# уютный_ADJ
# Уютная
# уютный_ADJ
# небрежное
# небрежный_ADJ
# быстро
# быстро_ADV
# деньги на ветер
# деньга_NOUN
# на_ADP
# ветер_NOUN
# Не стоит тех денег
# не_PART
# стоить_VERB
# тот_ADJ
# деньга_NOUN
# опытный
# опытный_ADJ
# приятный
# приятный_ADJ
# холодными
# холодное_NOUN
# быстро
# быстро_ADV
# комфортной
# комфортный_ADJ
# пресные
# пресный_ADJ
# обходительный
# обходительный_ADJ
# вежливый
# вежливый_ADJ
# по-домашнему
# по_ADP
# домашний_ADJ
# вкусно
# вкусно_ADV
# вкусно
# вкусно_ADV
# грязные
# грязный_ADJ
# приветливый
# приветливый_ADJ
# невкусный
# невкусный_ADJ
# не навязчивое
# не_PART
# навязчивый_ADJ
# вкусное
# вкусный_ADJ
# вкусный
# вкусный_ADJ
# дождался
# дождаться_VERB
# не очень вкусно
# не_PART
# очень_ADV
# вкусно_ADV
# суховат
# суховатый_ADJ
# вежливые
# вежливый_ADJ
# съедобным
# съедобный_ADJ
# безвкусный
# безвкусный_ADJ
# неисполнительность
# неисполнительность_NOUN
# уютно
# уютный_ADJ
# внимательно
# внимательно_ADV
# радушная
# радушный_ADJ
# уютная
# уютный_ADJ
# приветливый
# приветливый_ADJ
# невкусные
# невкусный_ADJ
# вкусный
# вкусный_ADJ
# уютный
# уютный_ADJ
# жесткий
# жёсткий_ADJ
# не очень улыбчивый
# не_PART
# очень_ADV
# улыбчивый_ADJ
# наивкуснейшей
# вкусный_ADJ
# пресное
# пресный_ADJ
# разнообразно
# разнообразно_ADV
# хамоват
# хамоватый_ADJ
# переплачивать
# переплачивать_VERB
# усталые
# усталый_ADJ
# медлительные
# медлительный_ADJ
# вкусный
# вкусный_ADJ
# чуть теплое
# чуть_ADV
# тёплый_ADJ
# красиво
# красиво_ADV
# вкусно
# вкусно_ADV
# хамоватая
# хамоватый_ADJ
# Милая
# милый_ADJ
# разбухшие
# разбухнуть_VERB
# вкусные
# вкусный_ADJ
# таяло во рту
# таять_VERB
# в_ADP
# рот_NOUN
# вкусно
# вкусно_ADV
# не вкусная
# не_PART
# вкусный_ADJ
# уютный
# уютный_ADJ
# не самый дешевый
# не_PART
# самый_ADJ
# дешёвый_ADJ
# сочное
# сочный_ADJ
# приветливые
# приветливый_ADJ
# вкусная
# вкусный_ADJ
# радушное
# радушный_ADJ
# Уютно
# уютный_ADJ
# приветливый
# приветливый_ADJ
# назойлив
# назойливый_ADJ
# тесновато
# тесновато_ADV
# дешево
# дёшево_ADV
# романтического
# романтический_ADJ
# невкусные
# невкусный_ADJ
# нежнейшим
# нежный_ADJ
# острое
# острый_ADJ
# мягких
# мягкий_ADJ
# дорогим
# дорогой_ADV
# вкусные
# вкусный_ADJ
# вкусная
# вкусный_ADJ
# пересушенные
# пересушить_VERB
# холодным
# холодное_NOUN
# тесно
# тесно_ADV
# расхлябанность
# расхлябанность_NOUN
# безвкусное
# безвкусный_ADJ
# свежайшему
# свежайший_ADJ
# неуютные
# неуютный_ADJ
# надменным
# надменный_ADJ
# не успевал
# не_PART
# успевать_VERB
# дорого
# дорого_ADV
# вежливости
# вежливость_NOUN
# вкусно
# вкусно_ADV
# приветлив
# приветливый_ADJ
# сочным
# сочный_ADJ
# предупредительно
# предупредительно_ADV
# медлителен
# медлительный_ADJ
# приветливой
# приветливый_ADJ
# сухая
# сухой_ADJ
# не уютно
# не_PART
# уютный_ADJ
# невкусный
# невкусный_ADJ
# вкуснее
# вкусный_ADJ
# дороговато
# дороговатый_ADJ
# дорого
# дорого_ADV
# готовят
# готовить_VERB
# приветливое
# приветливый_ADJ
# домашняя
# домашний_ADJ
# не вкусный
# не_PART
# вкусный_ADJ
# улыбающиеся
# улыбаться_VERB
# пересоленная
# пересолить_VERB
# пресноват
# пресноватый_ADJ
# милый
# милый_ADJ
# по-хамски
# по_ADP
# хамски_ADV
# долго
# долго_ADV
# вежливые
# вежливый_ADJ
# не навязчиво
# не_PART
# навязчивый_ADJ
# вежливый
# вежливый_ADJ
# вкусные
# вкусный_ADJ
# вежливая
# вежливый_ADJ
# холодный
# холодный_ADJ
# объедение
# объедение_NOUN
# вкусно
# вкусно_ADV
# невкусным
# невкусный_ADJ
# тесновато
# тесновато_ADV
# остывшее
# остыть_VERB
# не вкусный
# не_PART
# вкусный_ADJ
# приветливый
# приветливый_ADJ
# несоленый
# несолёный_ADJ
# вкусные
# вкусный_ADJ
# вкусный
# вкусный_ADJ
# дороже
# дорогой_ADV
# безвкусное
# безвкусный_ADJ
# галантный
# галантный_ADJ
# дороговато
# дороговатый_ADJ
# не досолена
# не_PART
# досолить_VERB
# Навязывание
# навязывание_NOUN
# грязный
# грязный_ADJ
# вкусно
# вкусно_ADV
# аккуратно
# аккуратно_ADV
# комфортный
# комфортный_ADJ
# дорого
# дорого_ADV
# остыл
# остылый_ADJ
# дружелюбный
# дружелюбный_ADJ
# вкусно
# вкусно_ADV
# неуютное
# неуютный_ADJ
# места мало
# место_NOUN
# мало_ADV
# засохшим
# засохнуть_VERB
# аккуратно
# аккуратно_ADV
# комки
# комок_NOUN
# Дешево
# дёшево_ADV
# не опрятно
# не_PART
# опрятно_ADV
# вкусным
# вкусный_ADJ
# хамство
# хамство_NOUN
# не дешевое
# не_PART
# дешёвый_ADJ
# ненавязчиво
# ненавязчивый_ADJ
# дорогой
# дорогой_ADV
# быстрые
# быстрый_ADJ
# вкусное
# вкусный_ADJ
# хамоватые
# хамоватый_ADJ
# приветливый
# приветливый_ADJ
# наелась
# наесться_VERB
# малоопытный
# малоопытный_ADJ
# навязчивый
# навязчивый_ADJ
# невкусное
# невкусный_ADJ
# хамски
# хамски_ADV
# ожидала лучшего
# ожидать_VERB
# хороший_ADJ
# забегаловку
# забегаловка_NOUN
# Быстрое
# быстрый_ADJ
# аншлаг
# аншлаг_NOUN
# четко
# чётко_ADV
# не удобно
# не_PART
# удобно_ADV
# вкусная
# вкусный_ADJ
# вкусные
# вкусный_ADJ
# долго
# долго_ADV
# красивый
# красивый_ADJ
# пресные
# пресный_ADJ
# вкусной
# вкусный_ADJ
# вкусное
# вкусный_ADJ
# не успевал
# не_PART
# успевать_VERB
# навязчиво
# навязчивый_ADJ
# вкуснейших
# вкусный_ADJ
# официантки
# официантка_NOUN
# тесно
# тесно_ADV
# суховата
# суховатый_ADJ
# дорого
# дорого_ADV
# дорогое
# дорогой_ADV
# бормочащие
# бормочить_VERB
# вкусная
# вкусный_ADJ
# галдеж
# галдёж_NOUN
# вежливые
# вежливый_ADJ
# сухие
# сухой_ADJ
# несъедобно
# несъедобный_ADJ
# шумно
# шумно_ADV
# дорого
# дорого_ADV
# не дешевый
# не_PART
# дешёвый_ADJ
# пересолено
# пересолить_VERB
# Милая
# милый_ADJ
# не вкусная
# не_PART
# вкусный_ADJ
# дороговат
# дороговатый_ADJ
# горьковато
# горьковатый_ADJ
# быстро
# быстро_ADV
# суховато
# суховато_ADV
# радовали глаз
# радовать_VERB
# глаз_NOUN
# не вкусно
# не_PART
# вкусно_ADV
# уютную
# уютный_ADJ
# вкусно
# вкусно_ADV
# не из дешевых
# не_PART
# из_ADP
# дешёвый_ADJ
# вежлив
# вежливый_ADJ
# Вкусное
# вкусный_ADJ
# внимателен
# внимательный_ADJ
# приветливые
# приветливый_ADJ
# забывчивость
# забывчивость_NOUN
# быстро
# быстро_ADV
# хамское
# хамский_ADJ
# оперативно
# оперативно_ADV
# места мало
# место_NOUN
# мало_ADV
# приветливый
# приветливый_ADJ
# вкусные
# вкусный_ADJ
# уютная
# уютный_ADJ
# любезный
# любезный_ADJ
# вежливые
# вежливый_ADJ
# сытные
# сытный_ADJ
# вкусно
# вкусно_ADV
# грубых
# грубый_ADJ
# игнором
# игнором_NOUN
# доброжелательных
# доброжелательный_ADJ
# дорогой
# дорогой_ADV
# не вкусный
# не_PART
# вкусный_ADJ
# чуть теплым
# чуть_ADV
# тёплый_ADJ
# жесткое
# жёсткий_ADJ
# не дешево
# не_PART
# дёшево_ADV
# невкусные
# невкусный_ADJ
# претензионная
# претензионный_ADJ
# суховато
# суховато_ADV
# доброжелательная
# доброжелательный_ADJ
# удобно
# удобно_ADV
# приветливые
# приветливый_ADJ
# таяло во рту
# таять_VERB
# в_ADP
# рот_NOUN
# нерасторопных
# нерасторопный_ADJ
# чистенько
# чистенько_ADV
# непрожарена
# непрожарить_VERB
# уютный
# уютный_ADJ
# Уютная
# уютный_ADJ
# небрежное
# небрежный_ADJ
# быстро
# быстро_ADV
# деньги на ветер
# деньга_NOUN
# на_ADP
# ветер_NOUN
# Не стоит тех денег
# не_PART
# стоить_VERB
# тот_ADJ
# деньга_NOUN
# опытный
# опытный_ADJ
# приятный
# приятный_ADJ
# холодными
# холодное_NOUN
# быстро
# быстро_ADV
# комфортной
# комфортный_ADJ
# пресные
# пресный_ADJ
# обходительный
# обходительный_ADJ
# вежливый
# вежливый_ADJ
# по-домашнему
# по_ADP
# домашний_ADJ
# вкусно
# вкусно_ADV
# вкусно
# вкусно_ADV
# грязные
# грязный_ADJ
# приветливый
# приветливый_ADJ
# невкусный
# невкусный_ADJ
# не навязчивое
# не_PART
# навязчивый_ADJ
# вкусное
# вкусный_ADJ
# вкусный
# вкусный_ADJ
# дождался
# дождаться_VERB
# не очень вкусно
# не_PART
# очень_ADV
# вкусно_ADV
# суховат
# суховатый_ADJ
# вежливые
# вежливый_ADJ
# съедобным
# съедобный_ADJ
# безвкусный
# безвкусный_ADJ
# неисполнительность
# неисполнительность_NOUN
# уютно
# уютный_ADJ
# внимательно
# внимательно_ADV
# радушная
# радушный_ADJ
# уютная
# уютный_ADJ
# приветливый
# приветливый_ADJ
# невкусные
# невкусный_ADJ
# вкусный
# вкусный_ADJ
# уютный
# уютный_ADJ
# жесткий
# жёсткий_ADJ
# не очень улыбчивый
# не_PART
# очень_ADV
# улыбчивый_ADJ
# наивкуснейшей
# вкусный_ADJ
# пресное
# пресный_ADJ
# разнообразно
# разнообразно_ADV
# хамоват
# хамоватый_ADJ
# переплачивать
# переплачивать_VERB
# усталые
# усталый_ADJ
# медлительные
# медлительный_ADJ
# вкусный
# вкусный_ADJ
# чуть теплое
# чуть_ADV
# тёплый_ADJ
# красиво
# красиво_ADV
# вкусно
# вкусно_ADV
# хамоватая
# хамоватый_ADJ
# Милая
# милый_ADJ
# разбухшие
# разбухнуть_VERB
# вкусные
# вкусный_ADJ
# таяло во рту
# таять_VERB
# в_ADP
# рот_NOUN
# вкусно
# вкусно_ADV
# не вкусная
# не_PART
# вкусный_ADJ
# уютный
# уютный_ADJ
# не самый дешевый
# не_PART
# самый_ADJ
# дешёвый_ADJ
# сочное
# сочный_ADJ
# приветливые
# приветливый_ADJ
# вкусная
# вкусный_ADJ
# радушное
# радушный_ADJ
# Уютно
# уютный_ADJ
# приветливый
# приветливый_ADJ
# назойлив
# назойливый_ADJ
# тесновато
# тесновато_ADV
# дешево
# дёшево_ADV
# романтического
# романтический_ADJ
# невкусные
# невкусный_ADJ
# нежнейшим
# нежный_ADJ
# острое
# острый_ADJ
# мягких
# мягкий_ADJ
# дорогим
# дорогой_ADV
# вкусные
# вкусный_ADJ
# вкусная
# вкусный_ADJ
# пересушенные
# пересушить_VERB
# холодным
# холодное_NOUN
# тесно
# тесно_ADV
# расхлябанность
# расхлябанность_NOUN
# безвкусное
# безвкусный_ADJ
# свежайшему
# свежайший_ADJ
# неуютные
# неуютный_ADJ
# надменным
# надменный_ADJ
# не успевал
# не_PART
# успевать_VERB
# дорого
# дорого_ADV
# вежливости
# вежливость_NOUN
# вкусно
# вкусно_ADV
# приветлив
# приветливый_ADJ
# сочным
# сочный_ADJ
# предупредительно
# предупредительно_ADV
# медлителен
# медлительный_ADJ
# приветливой
# приветливый_ADJ
# сухая
# сухой_ADJ
# не уютно
# не_PART
# уютный_ADJ
# невкусный
# невкусный_ADJ
# вкуснее
# вкусный_ADJ
# дороговато
# дороговатый_ADJ
# дорого
# дорого_ADV
# готовят
# готовить_VERB
# приветливое
# приветливый_ADJ
# домашняя
# домашний_ADJ
# не вкусный
# не_PART
# вкусный_ADJ
# улыбающиеся
# улыбаться_VERB
# пересоленная
# пересолить_VERB
# пресноват
# пресноватый_ADJ
# милый
# милый_ADJ
# по-хамски
# по_ADP
# хамски_ADV
# долго
# долго_ADV
# вежливые
# вежливый_ADJ
# не навязчиво
# не_PART
# навязчивый_ADJ
# вежливый
# вежливый_ADJ
# вкусные
# вкусный_ADJ
# вежливая
# вежливый_ADJ
# холодный
# холодный_ADJ
# объедение
# объедение_NOUN
# вкусно
# вкусно_ADV
# невкусным
# невкусный_ADJ
# тесновато
# тесновато_ADV
# остывшее
# остыть_VERB
# не вкусный
# не_PART
# вкусный_ADJ
# приветливый
# приветливый_ADJ
# несоленый
# несолёный_ADJ
# вкусные
# вкусный_ADJ
# вкусный
# вкусный_ADJ
# дороже
# дорогой_ADV
# безвкусное
# безвкусный_ADJ
# галантный
# галантный_ADJ
# дороговато
# дороговатый_ADJ
# не досолена
# не_PART
# досолить_VERB
# Навязывание
# навязывание_NOUN
# грязный
# грязный_ADJ
# вкусно
# вкусно_ADV
# аккуратно
# аккуратно_ADV
# комфортный
# комфортный_ADJ
# дорого
# дорого_ADV
# остыл
# остылый_ADJ
# дружелюбный
# дружелюбный_ADJ
# вкусно
# вкусно_ADV
# неуютное
# неуютный_ADJ
# места мало
# место_NOUN
# мало_ADV
# засохшим
# засохнуть_VERB
# аккуратно
# аккуратно_ADV
# комки
# комок_NOUN
# Дешево
# дёшево_ADV
# не опрятно
# не_PART
# опрятно_ADV
# вкусным
# вкусный_ADJ
# хамство
# хамство_NOUN
# не дешевое
# не_PART
# дешёвый_ADJ
# ненавязчиво
# ненавязчивый_ADJ
# дорогой
# дорогой_ADV
# быстрые
# быстрый_ADJ
# вкусное
# вкусный_ADJ
# хамоватые
# хамоватый_ADJ
# приветливый
# приветливый_ADJ
# наелась
# наесться_VERB
# малоопытный
# малоопытный_ADJ
# навязчивый
# навязчивый_ADJ
# невкусное
# невкусный_ADJ
# хамски
# хамски_ADV
# ожидала лучшего
# ожидать_VERB
# хороший_ADJ
# забегаловку
# забегаловка_NOUN
# Быстрое
# быстрый_ADJ
# аншлаг
# аншлаг_NOUN
# четко
# чётко_ADV
# не удобно
# не_PART
# удобно_ADV
# вкусная
# вкусный_ADJ
# вкусные
# вкусный_ADJ
# долго
# долго_ADV
# красивый
# красивый_ADJ
# пресные
# пресный_ADJ
# вкусной
# вкусный_ADJ
# вкусное
# вкусный_ADJ
# не успевал
# не_PART
# успевать_VERB
# навязчиво
# навязчивый_ADJ
# вкуснейших
# вкусный_ADJ
# официантки
# официантка_NOUN
# тесно
# тесно_ADV
# суховата
# суховатый_ADJ
# дорого
# дорого_ADV
# дорогое
# дорогой_ADV
# бормочащие
# бормочить_VERB
# вкусная
# вкусный_ADJ
# галдеж
# галдёж_NOUN
# вежливые
# вежливый_ADJ
# сухие
# сухой_ADJ
# несъедобно
# несъедобный_ADJ
# шумно
# шумно_ADV
# дорого
# дорого_ADV
# не дешевый
# не_PART
# дешёвый_ADJ
# пересолено
# пересолить_VERB
# Милая
# милый_ADJ
# не вкусная
# не_PART
# вкусный_ADJ
# дороговат
# дороговатый_ADJ
# горьковато
# горьковатый_ADJ
# быстро
# быстро_ADV
# 0.869169960474 0.0516909670099
# array(['negative', 'negative'], dtype=object)

# %%
df1
# Out:
#   class                       text
# 0     1             отвратительный
# 1     2                     быстро
# 2     0  очень плохое обслуживание
# 3     1              отличное меню

# %%
def predictor(word, pipeline):
    print(pipeline.predict(word))

# %%
predictor(df1.text, pipeline)
# Out:
# отличный_ADJ
# выбор_NOUN
# не_PART
# советовать_VERB
# очень_ADV
# советовать_VERB
# очень_ADV
# дорого_ADV
# выше_ADV
# всякий_ADJ
# похвала_NOUN
# в_ADP
# общий_ADJ
# прекрасно_ADV
# мы_PRON
# весь_ADJ
# понравиться_VERB
# ['positive' 'negative' 'negative' 'negative' 'negative' 'negative'
#  'positive']
